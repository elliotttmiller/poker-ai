# %% [markdown]
# # PokerMind Data Analysis
#
# This notebook analyzes poker game data, decision patterns, and performance metrics from PokerMind agent.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
from pathlib import Path

# Set up plotting
plt.style.use('seaborn-v0_8')
sns.set_palette('husl')

# Load data
data_dir = Path('../data/hand_history')
print(f"Looking for data in: {data_dir}")

# %% [markdown]
# ## Load Decision Packets
#
# Load and analyze the decision packets generated by PokerMind.

# %%
# TODO: Implement decision packet loading and analysis
# This will analyze:
# - Decision timing (System 1 vs System 2 processing times)
# - Confidence scores over time
# - GTO vs exploitative decision ratios
# - Opponent modeling accuracy

# %% [markdown]
# ## Performance Analysis
#
# Analyze win rates, decision quality, and learning progression.

# %%
# TODO: Implement performance analysis
# This will show:
# - Win rate over time
# - Decision accuracy vs confidence
# - Module performance breakdown
